# %%
# Standard library + third-party imports
import logging
import math
from functools import cached_property
from textwrap import dedent

import numpy as np
import numpy.random as rnd
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx

# Show INFO-level log messages from GetMatricesSCA (e.g. ghost-level warnings,
# export paths). Set to DEBUG if you want per-gamma parse output.
logging.basicConfig(level=logging.INFO, format="%(levelname)s: %(message)s")

# %%
# Import custom functions and classes
from get_sca_matrices import (make_levels_and_vertices, get_gamma_objects, get_gamma_energies, get_singles,
                              get_coincidences, get_adjacency, print_level_scheme, export_matrices)
from nuclear_objects import LSGraph, Gamma, Level, LevelScheme, TransitionScheme

data_file = "Ta182_beta.gam"
# data_file = "Am241.gam"

Glevel = make_levels_and_vertices(data_file)
gammas = get_gamma_objects()
print_level_scheme()
# Out:
# Level: 0.0
# Level: 1289.149
#   Gamma: 31.7377 keV  BR: 0.0141  Final state: 1257.412
#   Gamma: 67.7497 keV  BR: 0.6923  Final state: 1221.4
#   Gamma: 959.73 keV  BR: 0.0056  Final state: 329.4268
#   Gamma: 1189.04 keV  BR: 0.2659  Final state: 100.1059
#   Gamma: 1289.145 keV  BR: 0.0221  Final state: 0.0
# Level: 1373.83
#   Gamma: 42.7148 keV  BR: 0.0233  Final state: 1331.115
#   Gamma: 84.68024 keV  BR: 0.2307  Final state: 1289.149
#   Gamma: 116.4179 keV  BR: 0.0386  Final state: 1257.412
#   Gamma: 152.42991 keV  BR: 0.6100  Final state: 1221.4
#   Gamma: 1044.42 keV  BR: 0.0208  Final state: 329.4268
#   Gamma: 1273.719 keV  BR: 0.0574  Final state: 100.1059
#   Gamma: 1373.824 keV  BR: 0.0193  Final state: 0.0
# Level: 1487.501
#   Gamma: 44.66 keV  BR: 0.0047  Final state: 1442.836
#   Gamma: 113.6717 keV  BR: 0.2924  Final state: 1373.83
#   Gamma: 156.3864 keV  BR: 0.4174  Final state: 1331.115
#   Gamma: 198.35187 keV  BR: 0.2289  Final state: 1289.149
#   Gamma: 1158.1 keV  BR: 0.0452  Final state: 329.4268
#   Gamma: 1387.39 keV  BR: 0.0114  Final state: 100.1059
# Level: 1553.224
#   Gamma: 65.72215 keV  BR: 0.1704  Final state: 1487.501
#   Gamma: 110.393 keV  BR: 0.0061  Final state: 1442.836
#   Gamma: 179.39381 keV  BR: 0.1764  Final state: 1373.83
#   Gamma: 222.1085 keV  BR: 0.4278  Final state: 1331.115
#   Gamma: 264.074 keV  BR: 0.2043  Final state: 1289.149
#   Gamma: 1223.6 keV  BR: 0.0134  Final state: 329.4268
#   Gamma: 1453.12 keV  BR: 0.0017  Final state: 100.1059
# Level: 100.1059
#   Gamma: 100.10595 keV  BR: 1.0000  Final state: 0.0
# Level: 1257.412
#   Gamma: 121.5 keV  BR: 0.0008  Final state: 1135.91
#   Gamma: 928.0 keV  BR: 0.2147  Final state: 329.4268
#   Gamma: 1157.302 keV  BR: 0.2565  Final state: 100.1059
#   Gamma: 1257.407 keV  BR: 0.5281  Final state: 0.0
# Level: 329.4268
#   Gamma: 229.3207 keV  BR: 1.0000  Final state: 100.1059
# Level: 680.45
#   Gamma: 351.02 keV  BR: 1.0000  Final state: 329.4268
# Level: 1510.25
#   Gamma: 829.9 keV  BR: 0.0999  Final state: 680.45
#   Gamma: 1180.85 keV  BR: 0.6195  Final state: 329.4268
#   Gamma: 1410.13 keV  BR: 0.2805  Final state: 100.1059
# Level: 1221.4
#   Gamma: 891.7 keV  BR: 0.0009  Final state: 329.4268
#   Gamma: 1121.29 keV  BR: 0.5636  Final state: 100.1059
#   Gamma: 1221.395 keV  BR: 0.4355  Final state: 0.0
# Level: 1331.115
#   Gamma: 1001.7 keV  BR: 0.1523  Final state: 329.4268
#   Gamma: 1231.004 keV  BR: 0.8477  Final state: 100.1059
# Level: 1135.91
#   Gamma: 1035.7 keV  BR: 1.0000  Final state: 100.1059
#   Gamma: 1135.9 keV  BR: 0.0000  Final state: 0.0
# Level: 1442.836
#   Gamma: 1113.41 keV  BR: 0.6342  Final state: 329.4268
#   Gamma: 1342.73 keV  BR: 0.3658  Final state: 100.1059

# %%
# Build the three matrices. nc = normalization / count scaling factor.
nc = 10000

S = get_singles(nc)                  # list[float], length = N_gammas
C = get_coincidences(Glevel, nc)     # np.ndarray, shape (N, N) — symmetric
w = get_adjacency()                  # np.ndarray, shape (N, N) — branching ratios

print(f"Number of gamma-ray transitions: {len(S)}")
print(f"Coincidence matrix C shape:      {C.shape}")
print(f"Adjacency matrix  w shape:       {w.shape}")
print(f"C is symmetric:                   {np.allclose(C, C.T)}")
# Out:
# Computing coincidences: 100%|█████████████████████████████████████████████████████| 14/14 [00:00<00:00, 3497.13level/s]
# Number of gamma-ray transitions: 44
# Coincidence matrix C shape:      (44, 44)
# Adjacency matrix  w shape:       (44, 44)
# C is symmetric:                   True

# %%
# Optional: dump S, C, A to labelled CSVs (rows/cols are gamma energies in keV).
# Uncomment to write to ./matrices_out/.
# export_matrices(S, C, w, output_dir="matrices_out")

# %%
ts = TransitionScheme()                      # Initialize transition-centric scheme
ts.build_from_adjacency_matrix(w, 0, gammas) # Build transition scheme from A matrix
# Threshold is the smallest matrix element considered a real coincidence.
# Out:
# {31.7377: [121.5, 928.0, 1157.302, 1257.407], 42.7148: [1001.7, 1231.004], 44.66: [1113.41, 1342.73], 65.72215: [44.66, 113.6717, 156.3864, 198.35187, 1158.1, 1387.39], 67.7497: [891.7, 1121.29, 1221.395], 84.68024: [31.7377, 67.7497, 959.73, 1189.04, 1289.145], 100.10595: [], 110.393: [1113.41, 1342.73], 113.6717: [42.7148, 84.68024, 116.4179, 152.42991, 1044.42, 1273.719, 1373.824], 116.4179: [121.5, 928.0, 1157.302, 1257.407], 121.5: [1035.7], 152.42991: [891.7, 1121.29, 1221.395], 156.3864: [1001.7, 1231.004], 179.39381: [42.7148, 84.68024, 116.4179, 152.42991, 1044.42, 1273.719, 1373.824], 198.35187: [31.7377, 67.7497, 959.73, 1189.04, 1289.145], 222.1085: [1001.7, 1231.004], 229.3207: [100.10595], 264.074: [31.7377, 67.7497, 959.73, 1189.04, 1289.145], 351.02: [229.3207], 829.9: [351.02], 891.7: [229.3207], 928.0: [229.3207], 959.73: [229.3207], 1001.7: [229.3207], 1035.7: [100.10595], 1044.42: [229.3207], 1113.41: [229.3207], 1121.29: [100.10595], 1135.9: [], 1157.302: [100.10595], 1158.1: [229.3207], 1180.85: [229.3207], 1189.04: [100.10595], 1221.395: [], 1223.6: [229.3207], 1231.004: [100.10595], 1257.407: [], 1273.719: [100.10595], 1289.145: [], 1342.73: [100.10595], 1373.824: [], 1387.39: [100.10595], 1410.13: [100.10595], 1453.12: [100.10595]}

# %%
for bn in ts.branch_nodes:      # branch nodes are followed by adjacent transitions
    for ln in ts.leaf_nodes:    # leaf nodes have no outgoing transitions
        ts.find_all_paths(bn, ln)
print(f"Total cascade paths found: {len(ts.all_paths)}")
# Out:
# Total cascade paths found: 318

# %%
ls = LevelScheme()                  # Initialize level-centric scheme
ls.map_from_transition_space(ts)    # Map TS to level-space with minimal assumptions
ls.connect_nodes_with_edges()       # Add edges for gamma-ray transitions
ls.delete_edges_and_nodes()         # Remove redundant edges/nodes

# %%
plt.figure(figsize=(8, 6))
nx.draw_networkx(ls.g)
plt.title("LevelScheme after initial TS -> LS mapping")
plt.show()

for lvl in ls.levels:
    print(f"Node #{lvl}")
    print("  Incoming Gammas: ", [g.gE for g in ls.levels[lvl].in_gammas])
    print("  Outgoing Gammas: ", [g.gE for g in ls.levels[lvl].out_gammas])

print("Redundant nodes:", [lvl for lvl in ls.levels if lvl in ls.dummy_nodes])
# Out:
# Node #0
#   Incoming Gammas:  [121.5]
#   Outgoing Gammas:  [1035.7]
# Node #5
#   Incoming Gammas:  [1257.407]
#   Outgoing Gammas:  []
# Node #7
#   Incoming Gammas:  [229.3207, 1035.7, 1273.719, 1189.04, 1121.29, 1387.39, 1342.73, 1231.004, 1157.302, 1410.13, 1453.12]
#   Outgoing Gammas:  [100.10595]
# Node #8
#   Incoming Gammas:  [100.10595]
#   Outgoing Gammas:  []
# Node #14
#   Incoming Gammas:  [44.66, 110.393]
#   Outgoing Gammas:  [1113.41, 1342.73]
# Node #15
#   Incoming Gammas:  [65.72215]
#   Outgoing Gammas:  [44.66, 113.6717, 156.3864, 198.35187, 1158.1, 1387.39]
# Node #17
#   Incoming Gammas:  []
#   Outgoing Gammas:  [65.72215]
# Node #18
#   Incoming Gammas:  [113.6717, 179.39381]
#   Outgoing Gammas:  [42.7148, 84.68024, 116.4179, 152.42991, 1044.42, 1273.719, 1373.824]
# Node #19
#   Incoming Gammas:  [156.3864, 42.7148, 222.1085]
#   Outgoing Gammas:  [1001.7, 1231.004]
# Node #23
#   Incoming Gammas:  [84.68024, 198.35187, 264.074]
#   Outgoing Gammas:  [31.7377, 67.7497, 959.73, 1189.04, 1289.145]
# Node #24
#   Incoming Gammas:  [116.4179, 31.7377]
#   Outgoing Gammas:  [121.5, 928.0, 1157.302, 1257.407]
# Node #25
#   Incoming Gammas:  [152.42991, 67.7497]
#   Outgoing Gammas:  [891.7, 1121.29, 1221.395]
# Node #26
#   Incoming Gammas:  [1044.42, 959.73, 891.7, 1158.1, 1113.41, 1001.7, 928.0, 351.02, 1180.85, 1223.6]
#   Outgoing Gammas:  [229.3207]
# Node #28
#   Incoming Gammas:  [1373.824]
#   Outgoing Gammas:  []
# Node #32
#   Incoming Gammas:  [1289.145]
#   Outgoing Gammas:  []
# Node #35
#   Incoming Gammas:  [1221.395]
#   Outgoing Gammas:  []
# Node #36
#   Incoming Gammas:  []
#   Outgoing Gammas:  [110.393]
# Node #37
#   Incoming Gammas:  []
#   Outgoing Gammas:  [179.39381]
# Node #38
#   Incoming Gammas:  []
#   Outgoing Gammas:  [222.1085]
# Node #39
#   Incoming Gammas:  []
#   Outgoing Gammas:  [264.074]
# Node #40
#   Incoming Gammas:  [829.9]
#   Outgoing Gammas:  [351.02]
# Node #41
#   Incoming Gammas:  []
#   Outgoing Gammas:  [829.9]
# Node #42
#   Incoming Gammas:  []
#   Outgoing Gammas:  [1180.85]
# Node #43
#   Incoming Gammas:  []
#   Outgoing Gammas:  [1223.6]
# Node #44
#   Incoming Gammas:  []
#   Outgoing Gammas:  [1410.13]
# Node #45
#   Incoming Gammas:  []
#   Outgoing Gammas:  [1453.12]
# Redundant nodes: []

# %%
ls.build_gamma_cascades(ts)   # Dict of all gamma-ray pathways between two nodes
ls.compute_path_lengths()     # Path lengths = sum of gamma energies along cascade

# %%
print(ls.path_lengths)
ls.merge_redundant_leaves(energy_threshold=1)   # Tolerance in keV
ls.delete_edges_and_nodes()
# Out:
# {(23, 8): 1289.096892857143, (23, 5): 1289.1446999999998, (18, 8): 1373.78465, (15, 8): 1487.4643979310347, (17, 8): 1553.1865479310354, (17, 35): 1553.2187566666664, (17, 5): 1553.2187533333333, (17, 32): 1553.219055, (17, 28): 1553.21785, (23, 35): 1289.1447, (18, 35): 1373.8249250000001, (18, 5): 1373.82492, (18, 32): 1373.82524, (36, 8): 1553.2293000000004, (15, 35): 1487.4966066666666, (15, 5): 1487.496603333333, (15, 32): 1487.496905, (15, 28): 1487.4957000000002, (24, 8): 1257.3801833333332, (37, 8): 1553.17846, (37, 35): 1553.218735, (37, 5): 1553.21873, (37, 32): 1553.21905, (37, 28): 1553.21781, (38, 8): 1553.2268, (26, 8): 329.42665, (39, 8): 1553.1708928571427, (39, 35): 1553.2187, (39, 5): 1553.2187, (39, 32): 1553.219, (40, 8): 680.44665, (41, 8): 1510.34665, (25, 8): 1221.2613000000001, (19, 8): 1331.1183, (0, 8): 1135.80595, (14, 8): 1442.8363000000004, (42, 8): 1510.2766499999998, (43, 8): 1553.0266499999998, (44, 8): 1510.2359500000002, (45, 8): 1553.22595}
# New edge:  (24, 8)
# New edge:  (25, 8)
# New edge:  (23, 8)
# New edge:  (18, 8)
# Updated edges:  [(24, 8), (25, 8), (23, 8), (18, 8)]

# %%
plt.figure(figsize=(8, 6))
nx.draw_networkx(ls.g)
plt.title("LevelScheme after merging redundant leaves")
plt.show()

# %%
ls.find_leaf_nodes()
ls.leaf_node_deexcitation_energies()
ls.leaf_node_incoming_intensity(gammas, S)
# Out:
# Maximum energy lost when populating leaf nodes:  {(45, 8): 1553.2293000000004}
# Total number of gammas going into each leaf node:  {8: 1263770.0}

# %%
# Node corresponding to the ground state; currently user-specified.
# Adjust if you switch data files.
ls.compute_level_energies(gs_node=8)

# %%
for node in ls.g.nodes:
    print(f"Node: {node}   Energy: {ls.g.nodes[node]['energy']}")
    print("  Incoming gammas:", [g.gE for g in ls.levels[node].in_gammas])
    print("  Outgoing gammas:", [g.gE for g in ls.levels[node].out_gammas])
    print("-" * 40)
# Out:
# Node: 0   Energy: 1135.90635
#   Incoming gammas: [121.5]
#   Outgoing gammas: [1035.7]
# ----------------------------------------
# Node: 7   Energy: 100.10595
#   Incoming gammas: [229.3207, 1035.7, 1273.719, 1189.04, 1121.29, 1387.39, 1342.73, 1231.004, 1157.302, 1410.13, 1453.12]
#   Outgoing gammas: [100.10595]
# ----------------------------------------
# Node: 8   Energy: 0.0
#   Incoming gammas: [100.10595, 1257.407, 1221.395, 1289.145, 1373.824]
#   Outgoing gammas: []
# ----------------------------------------
# Node: 14   Energy: 1442.8359500000001
#   Incoming gammas: [44.66, 110.393]
#   Outgoing gammas: [1113.41, 1342.73]
# ----------------------------------------
# Node: 15   Energy: 1487.49595
#   Incoming gammas: [65.72215]
#   Outgoing gammas: [44.66, 113.6717, 156.3864, 198.35187, 1158.1, 1387.39]
# ----------------------------------------
# Node: 17   Energy: 1553.2181
#   Incoming gammas: []
#   Outgoing gammas: [65.72215]
# ----------------------------------------
# Node: 18   Energy: 1373.82425
#   Incoming gammas: [113.6717, 179.39381]
#   Outgoing gammas: [42.7148, 84.68024, 116.4179, 152.42991, 1044.42, 1273.719, 1373.824]
# ----------------------------------------
# Node: 19   Energy: 1331.10955
#   Incoming gammas: [156.3864, 42.7148, 222.1085]
#   Outgoing gammas: [1001.7, 1231.004]
# ----------------------------------------
# Node: 23   Energy: 1289.14408
#   Incoming gammas: [84.68024, 198.35187, 264.074]
#   Outgoing gammas: [31.7377, 67.7497, 959.73, 1189.04, 1289.145]
# ----------------------------------------
# Node: 24   Energy: 1257.40635
#   Incoming gammas: [116.4179, 31.7377]
#   Outgoing gammas: [121.5, 928.0, 1157.302, 1257.407]
# ----------------------------------------
# Node: 25   Energy: 1221.3943399999998
#   Incoming gammas: [152.42991, 67.7497]
#   Outgoing gammas: [891.7, 1121.29, 1221.395]
# ----------------------------------------
# Node: 26   Energy: 329.42595000000006
#   Incoming gammas: [1044.42, 959.73, 891.7, 1158.1, 1113.41, 1001.7, 928.0, 351.02, 1180.85, 1223.6]
#   Outgoing gammas: [229.3207]
# ----------------------------------------
# Node: 36   Energy: 1553.2289500000002
#   Incoming gammas: []
#   Outgoing gammas: [110.393]
# ----------------------------------------
# Node: 37   Energy: 1553.21806
#   Incoming gammas: []
#   Outgoing gammas: [179.39381]
# ----------------------------------------
# Node: 38   Energy: 1553.21805
#   Incoming gammas: []
#   Outgoing gammas: [222.1085]
# ----------------------------------------
# Node: 39   Energy: 1553.21808
#   Incoming gammas: []
#   Outgoing gammas: [264.074]
# ----------------------------------------
# Node: 40   Energy: 680.44595
#   Incoming gammas: [829.9]
#   Outgoing gammas: [351.02]
# ----------------------------------------
# Node: 41   Energy: 1510.34595
#   Incoming gammas: []
#   Outgoing gammas: [829.9]
# ----------------------------------------
# Node: 42   Energy: 1510.27595
#   Incoming gammas: []
#   Outgoing gammas: [1180.85]
# ----------------------------------------
# Node: 43   Energy: 1553.02595
#   Incoming gammas: []
#   Outgoing gammas: [1223.6]
# ----------------------------------------
# Node: 44   Energy: 1510.2359500000002
#   Incoming gammas: []
#   Outgoing gammas: [1410.13]
# ----------------------------------------
# Node: 45   Energy: 1553.22595
#   Incoming gammas: []
#   Outgoing gammas: [1453.12]
# ----------------------------------------

# %%
ls.merge_redundant_roots(energy_threshold=1)
ls.delete_edges_and_nodes()

# %%
for edge in ls.g.edges:
    print(
        f"Edge: {edge}  "
        f"Gamma energy: {ls.g.edges[edge]['energy']}  "
        f"Branching ratio: {ls.g.edges[edge]['weight']:.4f}"
    )
# Out:
# Edge: (0, 7)  Gamma energy: 1035.7  Branching ratio: 1.0000
# Edge: (7, 8)  Gamma energy: 100.10595  Branching ratio: 1.0000
# Edge: (14, 7)  Gamma energy: 1342.73  Branching ratio: 0.3658
# Edge: (14, 26)  Gamma energy: 1113.41  Branching ratio: 0.6342
# Edge: (15, 7)  Gamma energy: 1387.39  Branching ratio: 0.0114
# Edge: (15, 14)  Gamma energy: 44.66  Branching ratio: 0.0047
# Edge: (15, 18)  Gamma energy: 113.6717  Branching ratio: 0.2924
# Edge: (15, 19)  Gamma energy: 156.3864  Branching ratio: 0.4174
# Edge: (15, 23)  Gamma energy: 198.35187  Branching ratio: 0.2289
# Edge: (15, 26)  Gamma energy: 1158.1  Branching ratio: 0.0452
# Edge: (17, 15)  Gamma energy: 65.72215  Branching ratio: 0.1704
# Edge: (18, 7)  Gamma energy: 1273.719  Branching ratio: 0.0574
# Edge: (18, 19)  Gamma energy: 42.7148  Branching ratio: 0.0233
# Edge: (18, 23)  Gamma energy: 84.68024  Branching ratio: 0.2307
# Edge: (18, 24)  Gamma energy: 116.4179  Branching ratio: 0.0386
# Edge: (18, 25)  Gamma energy: 152.42991  Branching ratio: 0.6100
# Edge: (18, 26)  Gamma energy: 1044.42  Branching ratio: 0.0208
# Edge: (18, 8)  Gamma energy: 1373.824  Branching ratio: 0.0193
# Edge: (19, 7)  Gamma energy: 1231.004  Branching ratio: 0.8477
# Edge: (19, 26)  Gamma energy: 1001.7  Branching ratio: 0.1523
# Edge: (23, 7)  Gamma energy: 1189.04  Branching ratio: 0.2659
# Edge: (23, 24)  Gamma energy: 31.7377  Branching ratio: 0.0141
# Edge: (23, 25)  Gamma energy: 67.7497  Branching ratio: 0.6923
# Edge: (23, 26)  Gamma energy: 959.73  Branching ratio: 0.0056
# Edge: (23, 8)  Gamma energy: 1289.145  Branching ratio: 0.0221
# Edge: (24, 0)  Gamma energy: 121.5  Branching ratio: 0.0008
# Edge: (24, 7)  Gamma energy: 1157.302  Branching ratio: 0.2565
# Edge: (24, 26)  Gamma energy: 928.0  Branching ratio: 0.2147
# Edge: (24, 8)  Gamma energy: 1257.407  Branching ratio: 0.5281
# Edge: (25, 7)  Gamma energy: 1121.29  Branching ratio: 0.5636
# Edge: (25, 26)  Gamma energy: 891.7  Branching ratio: 0.0009
# Edge: (25, 8)  Gamma energy: 1221.395  Branching ratio: 0.4355
# Edge: (26, 7)  Gamma energy: 229.3207  Branching ratio: 1.0000
# Edge: (36, 14)  Gamma energy: 110.393  Branching ratio: 0.0061
# Edge: (37, 18)  Gamma energy: 179.39381  Branching ratio: 0.1764
# Edge: (38, 19)  Gamma energy: 222.1085  Branching ratio: 0.4278
# Edge: (39, 23)  Gamma energy: 264.074  Branching ratio: 0.2043
# Edge: (40, 26)  Gamma energy: 351.02  Branching ratio: 1.0000
# Edge: (41, 40)  Gamma energy: 829.9  Branching ratio: 0.0999
# Edge: (42, 26)  Gamma energy: 1180.85  Branching ratio: 0.6195
# Edge: (43, 26)  Gamma energy: 1223.6  Branching ratio: 0.0134
# Edge: (44, 7)  Gamma energy: 1410.13  Branching ratio: 0.2805
# Edge: (45, 7)  Gamma energy: 1453.12  Branching ratio: 0.0017

# %%
from plotting import draw_level_scheme, draw_transition_scheme

num_levels = len(ls.levels)
fig = plt.figure(figsize=(max(num_levels, 6), max(num_levels, 6)))
ax = plt.gca()
draw_level_scheme(ls, ax, branch=True)
plt.title("Reconstructed level scheme")
plt.show()

# %%
ls.leaf_nodes
# Out:
# [8]
